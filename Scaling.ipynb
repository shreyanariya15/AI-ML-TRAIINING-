# %% [markdown]
#  Step 1 : Importing necessary libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 2 : Creating the data

# %%
data = {
    'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65],
    'Salary':[2000,25000,30000,80000,12000,27000,70000,150000,100000],
    'Purchased':[0,0,0,1,0,0,1,1,1]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Age  Salary  Purchased
# 0   25    2000          0
# 1   30   25000          0
# 2   35   30000          0
# 3   40   80000          1
# 4   45   12000          0
# 5   50   27000          0
# 6   55   70000          1
# 7   60  150000          1
# 8   65  100000          1

# %% [markdown]
# Step 3 : Splitting of data

# %%
x = df[['Age','Salary']]
y = df[['Purchased']]

# %% [markdown]
# Step 4 : Train-test split of the data

# %%
x_train , x_test , y_train , y_test = train_test_split(
    x,
    y,
    test_size=0.3,
    random_state = 42
)

# %% [markdown]
# Step 5: Knn without scaling

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(x_train,y_train)

y_pred = knn.predict(x_test)

print("Acuracy without scaling:",accuracy_score(y_test,y_pred))
# Out:
# Acuracy without scaling: 1.0
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# Step 6 : Apply Standar Scaller

# %%
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)

x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Step 7: KNN with scaling

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(x_train_scaled, y_train)
y_pred_scaled = knn.predict(x_test_scaled)

print("Accuracy with Scaling:", accuracy_score(y_test,y_pred))
# Out:
# Accuracy with Scaling: 1.0
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
scaled_df = pd.DataFrame(
    x_train_scaled,
    columns = ['Age','Salary']
)

print(scaled_df)
# Out:
#         Age    Salary
# 0 -1.469416 -1.291839
# 1  1.597191  1.401783
# 2 -0.702764 -0.522233
# 3  0.063888 -1.016980
# 4 -0.319438  0.852064
# 5  0.830540  0.577205
